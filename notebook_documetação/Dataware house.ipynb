# %% [markdown]
# ## Estudo de ETL no dataware house

# %% [markdown]
# #### 1 importe as bibliotecas necessárias

# %%
import pymysql
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine

# %% [markdown]
# #### 2.Conecte seu notebook ao RDS da AWS

# %%
engine_dwh = sqlalchemy.create_engine('mysql+pymysql://admin:mysqladmin1509@database-1.c2hbzw6k9btq.us-east-2.rds.amazonaws.com:3306/DW_F1')
engine_bdf1 = sqlalchemy.create_engine('mysql+pymysql://admin:mysqladmin1509@database-1.c2hbzw6k9btq.us-east-2.rds.amazonaws.com:3306/FORMULA1')

# %% [markdown]
# #### 3.Olhe a tabela fato de resultados

# %%
tabela_resultados = pd.read_sql_table("fato_resultados", engine_dwh)
tabela_resultados
# Out:
#        id_dim_construtor  id_dim_piloto  id_dim_corrida  id_dim_circuito  \
# 0                      2              9               1                1
# 1                      1              5               1                1
# 2                      2              2               1                1
# 3                      1              1               1                1
# 4                      2              9               2                2
# 5                      1              5               2                2
# 6                      2              2               2                2
# 7                      1              1               2                2
# 8                      2              9               3               17
# 9                      1              5               3               17
# 10                     2              2               3               17
# 11                     1              1               3               17
# ...

# %% [markdown]
# #### 5. quantas colisões aconteceram durante toda a f1?

# %%
tabela_interesse = pd.read_sql_table("fato_resultados", engine_dwh, columns=['status'])

tabela_colisao_analise = tabela_interesse.query('status =="Collision"')

tabela_colisao_analise

len(tabela_colisao_analise)
# Out:
# 806

# %% [markdown]
# #### 6. em todos esses anos, quantos pilotos nunca tiveram colisões de corrida enquanto atuavam na f1?

# %%
# quantidade total de pilotos 
tabela_dim_pilotos = pd.read_sql_table("dim_pilotos", engine_dwh)

qtd_pilotos = len(tabela_dim_pilotos)

qtd_piloto_sem_colisao = qtd_pilotos - qtd_piloto_colisao

print(f'Exatamente {qtd_piloto_sem_colisao} piltos não tiveram colisões durante as suas atuações na formula 1')
# Out:
# Exatamente 47 piltos não tiveram colisões durante as suas atuações na formula 1

# %% [markdown]
# #### 7. quais pilotos nunca colidiram em corridas?

# %%
tabela_resultados = pd.read_sql_table("fato_resultados", engine_dwh, columns=['id_dim_piloto','status'])
tabela_dim_pilotos = pd.read_sql_table("dim_pilotos", engine_dwh, columns=['id_dim_piloto','ref_piloto'])

tabela_so_colisao = tabela_resultados.query('status == "Collision"')

tabela_analise_piloto_colisao = pd.merge(tabela_dim_pilotos, tabela_so_colisao, how="right", on="id_dim_piloto")
qtd_colisao = len(tabela_so_colisao)

#tabela_analise_piloto_colisao

tabela_resposta_apenas = tabela_analise_piloto_colisao.drop_duplicates('ref_piloto', keep=False, inplace=False)

tabela_resposta
# Out:
#      id_dim_piloto     ref_piloto     status
# 41               6       nakajima  Collision
# 206             26          speed  Collision
# 207             29       yamamoto  Collision
# 229             33       monteiro  Collision
# 246             39    karthikeyan  Collision
# 247             41          zonta  Collision
# 248             42       pizzonia  Collision
# 249             43          matta  Collision
# 265             47    baumgartner  Collision
# 279             54          burti  Collision
# 316             58        marques  Collision
# 317             59       bernoldi  Collision
# 343             66         mcnish  Collision
# 373             74          tuero  Collision
# 374             75         nakano  Collision
# 375             76      magnussen  Collision
# 412             85     montermini  Collision
# 423             89          inoue  Collision
# 424             90         moreno  Collision
# 447             96       boullion  Collision
# ...

# %% [markdown]
# #### 6. qual o circuito que mais teve colisões ou seja, qual o circuito mais "perigoso"?

# %%
tabela_dim_circuitos = pd.read_sql_table("dim_circuitos", engine_dwh, columns=['id_dim_circuito', 'nome_circuito'])
tabela_resultados = pd.read_sql_table("fato_resultados", engine_dwh, columns=['id_dim_circuito', 'status'])
tabela_unida = pd.merge(tabela_dim_circuitos, tabela_resultados, how="right", on="id_dim_circuito")
tabela_unida

df.loc[:, df.columns != 'b']
# Out:
#        id_dim_circuito                         nome_circuito        status
# 0                    1        Albert Park Grand Prix Circuit     Collision
# 1                    1        Albert Park Grand Prix Circuit     Collision
# 2                    1        Albert Park Grand Prix Circuit      Finished
# 3                    1        Albert Park Grand Prix Circuit  Disqualified
# 4                    1        Albert Park Grand Prix Circuit     Collision
# 5                    1        Albert Park Grand Prix Circuit      Finished
# 6                    1        Albert Park Grand Prix Circuit      Finished
# 7                    1        Albert Park Grand Prix Circuit      Finished
# 8                    1        Albert Park Grand Prix Circuit       Gearbox
# 9                    1        Albert Park Grand Prix Circuit      Finished
# 10                   1        Albert Park Grand Prix Circuit      Finished
# ...

# %% [markdown]
# #### 5. Qual a volta mais rápida por ano ?

# %%
tabela_interesse = pd.read_sql_table("fato_resultados", engine_dwh, columns=)
tabela_circuito_analise = tabela_resultados.query('pais_circuito =="Brazil"')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\iuryf\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\computation\scope.py in resolve(self, key, is_local)
#     180             if self.has_resolvers:
# --> 181                 return self.resolvers[key]
#     182
#
# c:\users\iuryf\appdata\local\programs\python\python37-32\lib\collections\__init__.py in __getitem__(self, key)
#     915                 pass
# --> 916         return self.__missing__(key)            # support subclasses that define __missing__
#     917
#
# c:\users\iuryf\appdata\local\programs\python\python37-32\lib\collections\__init__.py in __missing__(self, key)
#     907     def __missing__(self, key):
# --> 908         raise KeyError(key)
#     909
#
# KeyError: 'pais_circuito'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
tabela_resultados = pd.read_sql_table("resultados", engine_bdf1)

tabela_status = pd.read_sql_table("status", engine_bdf1)
tabela_resultados.query('')
# Out:
#      id_status  descricao_status
# 0            1          Finished
# 1            2      Disqualified
# 2            3          Accident
# 3            4         Collision
# 4            5            Engine
# 5            6           Gearbox
# 6            7      Transmission
# 7            8            Clutch
# 8            9        Hydraulics
# 9           10        Electrical
# 10          11            +1 Lap
# 11          12           +2 Laps
# 12          13           +3 Laps
# 13          14           +4 Laps
# 14          15           +5 Laps
# 15          16           +6 Laps
# 16          17           +7 Laps
# 17          18           +8 Laps
# 18          19           +9 Laps
# 19          20          Spun off
# 20          21          Radiator
# 21          22        Suspension
# 22          23            Brakes
# 23          24      Differential
# 24          25       Overheating
# 25          26        Mechanical
# 26          27              Tyre
# ...
