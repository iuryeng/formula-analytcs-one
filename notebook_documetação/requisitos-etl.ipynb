# %% [markdown]
# ## Estudo ETL Formula1 data jupyter notebook
#  >projeto: Formula_Analitycs_One
#
#  >propósito do script: estudar o processo de ETL para gerar as informações de requisitos

# %% [markdown]
# ### 1. Instalação, configuração e teste de conexão com AWS

# %% [markdown]
# #### 1.1 instale as bibliotecas necessárias

# %%
#!pip install sqlalchemy
#!pip install pandas
#!pip install pymysql

# %% [markdown]
# #### 1.2 importe as bibliotecas necessárias

# %%
import pymysql
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine

# %% [markdown]
# #### 1.3 defina as variáveis de conexão com o drive pymysql e aws

# %%
AWS_DB_HOST = 'database-1.c2hbzw6k9btq.us-east-2.rds.amazonaws.com'
AWS_DB_USER = 'admin'
AWS_DB_PASS = 'mysqladmin1509'
AWS_DB_OLAT = 'DW_F1'

# %% [markdown]
# #### 1.4 teste a conexão para qualquer qulquer base de dados na aws

# %%
def teste_conexao_base_pymysql(bdados):
    """
    fução para conectar uma base qualquer na instancia da AWS
    """
    try:        
        pymysql.connect(host=AWS_DB_HOST,user=AWS_DB_USER,
        password=AWS_DB_PASS,
        database=bdados)
        print("Base de dados " + bdados + " conectada com sucesso!")

    except Exception as err:
        print("Falha na conexão")
        print(err)

# %% [markdown]
# #### 1.5 teste a conexao  para o OLAP na nuvem aws

# %%
teste_conexao_base_pymysql(AWS_DB_OLAT)
# Out:
# Base de dados DW_F1 conectada com sucesso!

# %% [markdown]
# #### 1.6 defina uma conexão  com uma base para o OLAP  do projeto via  engine sqlalchemy

# %%
engine_bdwf1 = sqlalchemy.create_engine('mysql+pymysql://admin:mysqladmin1509@database-1.c2hbzw6k9btq.us-east-2.rds.amazonaws.com:3306/DW_F1')
engine_bdwf1
# Out:
# Engine(mysql+pymysql://admin:***@database-1.c2hbzw6k9btq.us-east-2.rds.amazonaws.com:3306/DW_F1)

# %% [markdown]
# ### 2. Mineração de dados no DW

# %% [markdown]
# #### 2.1 lendo os dados das tabelas do dataware house e definindo variáveis globais de manipulação

# %%
fato_resultado = pd.read_sql_table("fato_resultados", engine_bdwf1)
dim_circuitos = pd.read_sql_table("dim_circuitos", engine_bdwf1)
dim_construtores = pd.read_sql_table("dim_construtores", engine_bdwf1)
dim_corridas = pd.read_sql_table("dim_corridas", engine_bdwf1)
dim_pilotos = pd.read_sql_table("dim_pilotos", engine_bdwf1)
dim_tempo = pd.read_sql_table("dim_tempo", engine_bdwf1)

# %% [markdown]
# #### 2.2 analisando a classificação de pilotos

# %% [markdown]
# 2.2.1 - limpe as tabelas para analisar os registros dentro dos interesses de requisitos

# %%
#limpe a tabela fato resultados apenas para as colunas de interesse na classificação de pilotos
classificacao_piloto = pd.read_sql_table("fato_resultados", engine_bdwf1, columns=['temporada','id_dim_piloto', 'id_dim_corrida', 'pontos_ganhos'])

#limpe a tabela  de dimensão pilotos apenas para as colunasref_piloto e nacionalidade
dim_piloto_interesse = pd.read_sql_table("dim_pilotos", engine_bdwf1, columns=['id_dim_piloto', 'ref_piloto', 'nacionalidade'])

# una as tabelas de interesse 
tabela_unida_interesse = pd.merge(classificacao_piloto, dim_piloto_interesse, on='id_dim_piloto')

#limpe a tabela  de dimensão corridas apenas apra as colunas id_dim_corrida e nome_gp
dim_corrida_interesse = pd.read_sql_table("dim_corridas", engine_bdwf1, columns=['id_dim_corrida', 'nome_gp'])

# adicione o nome do gp a tabela de interesse
tabela_unida_interesse = pd.merge(tabela_unida_interesse, dim_corrida_interesse, on='id_dim_corrida')

#filte a tabela unida de interesse para ficar com: ano da temporada, nome piloto, pais do piloto, pontos por corrida, nome da corrida, 
tabela_unida_interesse

#gere um dataframe de classificacao apenas apra as colunas temporada, nacionalidade, ref_piloto,  pontos_ganhos, nome_gp
classificacao = pd.DataFrame(tabela_unida_interesse, columns = ['temporada','ref_piloto','nacionalidade', 'nome_gp', 'pontos_ganhos'])

# %% [markdown]
# 2.2.1 - Exiba todos os pontos de cada corrida de um piloto especifico em uma temporada qualquer e tambem o total de pontos do piloto na temporada escolhida

# %%
def total_pontos_piloto_temporada(temporada, piloto):
    """
    Exibe todos os pontos por corrida de um piloto em uma temporada e calcula o total de pontos
    """
    filtro = classificacao[(classificacao['temporada']== temporada) & (classificacao['ref_piloto']== piloto)] 
    filtro = filtro.reset_index(drop=True)
    total_pontos = filtro['pontos_ganhos'].sum()
    print(f"Total de pontos do piloto {piloto} na temporada {temporada} é de {total_pontos} pontos")    
    filtro = filtro.drop(columns=['ref_piloto','temporada', 'nacionalidade'])
    filtro = filtro.T
    return filtro

# %% [markdown]
# 2.2.2 - Exiba o quais e quantos pilotos que participaram de uma determinada temporada

# %%
def pilotos_temporada(temporada):
    so_temporada_piloto = classificacao.query('temporada=="{}"'.format(temporada))
    lista_piloto_temporada = list(so_temporada_piloto['ref_piloto'].unique())
    qtd_pilotos_temporada =  len(lista_piloto_temporada)       
    return lista_piloto_temporada

# %% [markdown]
# 2.2.3 - Exiba apenas os pontos de um piloto em uma temporada

# %%
def apenas_pontos_piloto_temporada(temporada, piloto):
    """
    Exibe tapenas os pontos de um piloto em uma temporada
    """
    filtro = classificacao[(classificacao['temporada']== temporada) & (classificacao['ref_piloto']== piloto)] 
    filtro = filtro.reset_index(drop=True)
    total_pontos = filtro['pontos_ganhos'].sum()     
    filtro = filtro.drop(columns=['ref_piloto','nome_gp','temporada', 'nacionalidade'])
    filtro = filtro
    return filtro

# %% [markdown]
# 2.2.3 - Exiba apenas os nomes de todos os gps de uma temporada

# %%
def apenas_gps_temporada(temporada):
    """
    Exibe todos os pontos por corrida de um piloto em uma temporada e calcula o total de pontos
    """
    so_gps_temporada = classificacao.query('temporada=="{}"'.format(temporada))
    lista_piloto_temporada = list(so_gps_temporada['nome_gp'].unique())           
    return lista_piloto_temporada

# %% [markdown]
# 2.2.3 - Exiba pontuacao de pilotos por uma temporada qualquer

# %%
def pontuacao_pilotos_temporada(temporada):
    """
    retorna a pontuação de pilotos por uma temporada qualquer
    """
    array_pilotos = pilotos_temporada(temporada)
    data_pontos = []
    qtd_pilotos = len(array_pilotos)

    for x in range(qtd_pilotos):
        resultado = apenas_pontos_piloto_temporada(temporada, array_pilotos[x])
        lista = list(resultado.pontos_ganhos)
        data_pontos .append(lista)
   
    pontuacao_pilotos = pd.DataFrame(data=data_pontos ,index = pilotos_temporada(temporada), columns=apenas_gps_temporada(temporada))
    return pontuacao_pilotos

# %%
def array_total_pontos_pilotos_temporada(temporada):    
    """
    Detorna um array contendo o total de pontos dos pilotos por temporada
    """
    pilotos = pilotos_temporada(temporada)
    array_pontos_pilotos = []
    qtd_pilotos = len(pilotos)
    for x in range(qtd_pilotos):
        pontos_ganhos = apenas_pontos_piloto_temporada(temporada, pilotos[x])
        total_pontos =  pontos_ganhos['pontos_ganhos'].sum()  
        array_pontos_pilotos.append(total_pontos)
    return array_pontos_pilotos

# %%
def colocacao_pilotos_temporada(temporada):
    """
    Retorna um dataframe com o total de pontos dos pilotos por temporada
    """
    pilotos = pilotos_temporada(temporada)
    data_total_pontos = array_total_pontos_pilotos_temporada(temporada)
    df_classificacao = pd.DataFrame(data=data_total_pontos ,index = pilotos, columns=['total_pontos'])
    return df_classificacao

# %%
def classificacao_campeonato_pilotos(temporada):
    """
     retorna a classificacao do campeonato de pilotos 
    """
    array_pontos_pilotos = array_total_pontos_pilotos_temporada(temporada)
    df1 = colocacao_pilotos_temporada(temporada)
    df2 = pontuacao_pilotos_temporada(temporada)
    df2.insert(0, "total pontos", array_pontos_pilotos, True)
    classificacao_pilotos = df2.sort_values("total pontos", ascending=False)
    return classificacao_pilotos

# %% [markdown]
# ### 3. Resposta ao requisito de classificação de campeonato de pilotos

# %% [markdown]
# #### 3.1 exiba os registros de classificação de campeonato de piloto na tabela de fato resultados

# %%
classificacao.sort_values("temporada",ascending=False).head(10).style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23" ><thead>    <tr>        <th class="col_heading level0 col0" >temporada</th>        <th class="col_heading level0 col1" >ref_piloto</th>        <th class="col_heading level0 col2" >nacionalidade</th>        <th class="col_heading level0 col3" >nome_gp</th>        <th class="col_heading level0 col4" >pontos_ganhos</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row0_col0" class="data row0 col0" >2021</td>
#                         <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row0_col1" class="data row0 col1" >vettel</td>
#                         <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row0_col2" class="data row0 col2" >German</td>
#                         <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row0_col3" class="data row0 col3" >Bahrain Grand Prix</td>
#                         <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row0_col4" class="data row0 col4" >0</td>
#             </tr>
#             <tr>
#                                 <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row1_col0" class="data row1 col0" >2021</td>
#                         <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row1_col1" class="data row1 col1" >perez</td>
#                         <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row1_col2" class="data row1 col2" >Mexican</td>
#                         <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row1_col3" class="data row1 col3" >Emilia Romagna Grand Prix</td>
#                         <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row1_col4" class="data row1 col4" >0</td>
#             </tr>
#             <tr>
#                                 <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row2_col0" class="data row2 col0" >2021</td>
#                         <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row2_col1" class="data row2 col1" >gasly</td>
#                         <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row2_col2" class="data row2 col2" >French</td>
#                         <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row2_col3" class="data row2 col3" >Portuguese Grand Prix</td>
#                         <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row2_col4" class="data row2 col4" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row3_col0" class="data row3 col0" >2021</td>
#                         <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row3_col1" class="data row3 col1" >russell</td>
#                         <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row3_col2" class="data row3 col2" >British</td>
#                         <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row3_col3" class="data row3 col3" >Portuguese Grand Prix</td>
#                         <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row3_col4" class="data row3 col4" >0</td>
#             </tr>
#             <tr>
#                                 <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row4_col0" class="data row4 col0" >2021</td>
#                         <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row4_col1" class="data row4 col1" >norris</td>
#                         <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row4_col2" class="data row4 col2" >British</td>
#                         <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row4_col3" class="data row4 col3" >Portuguese Grand Prix</td>
#                         <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row4_col4" class="data row4 col4" >10</td>
#             </tr>
#             <tr>
#                                 <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row5_col0" class="data row5 col0" >2021</td>
#                         <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row5_col1" class="data row5 col1" >latifi</td>
#                         <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row5_col2" class="data row5 col2" >Canadian</td>
#                         <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row5_col3" class="data row5 col3" >Portuguese Grand Prix</td>
#                         <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row5_col4" class="data row5 col4" >0</td>
#             </tr>
#             <tr>
#                                 <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row6_col0" class="data row6 col0" >2021</td>
#                         <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row6_col1" class="data row6 col1" >tsunoda</td>
#                         <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row6_col2" class="data row6 col2" >Japanese</td>
#                         <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row6_col3" class="data row6 col3" >Portuguese Grand Prix</td>
#                         <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row6_col4" class="data row6 col4" >0</td>
#             </tr>
#             <tr>
#                                 <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row7_col0" class="data row7 col0" >2021</td>
#                         <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row7_col1" class="data row7 col1" >mick_schumacher</td>
#                         <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row7_col2" class="data row7 col2" >German</td>
#                         <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row7_col3" class="data row7 col3" >Portuguese Grand Prix</td>
#                         <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row7_col4" class="data row7 col4" >0</td>
#             </tr>
#             <tr>
#                                 <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row8_col0" class="data row8 col0" >2021</td>
#                         <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row8_col1" class="data row8 col1" >mazepin</td>
#                         <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row8_col2" class="data row8 col2" >Russian</td>
#                         <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row8_col3" class="data row8 col3" >Portuguese Grand Prix</td>
#                         <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row8_col4" class="data row8 col4" >0</td>
#             </tr>
#             <tr>
#                                 <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row9_col0" class="data row9 col0" >2021</td>
#                         <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row9_col1" class="data row9 col1" >mazepin</td>
#                         <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row9_col2" class="data row9 col2" >Russian</td>
#                         <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row9_col3" class="data row9 col3" >Bahrain Grand Prix</td>
#                         <td id="T_cf0ee740_d085_11eb_8d7e_00e04c0cab23row9_col4" class="data row9 col4" >0</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### 3.3 mostre a classificação do campeonato de pilotos por temporada

# %%
classificacao_campeonato_pilotos("1990")
# Out:
#                  total pontos  Mexican Grand Prix  Japanese Grand Prix  \
# senna                      78                   0                    0
# prost                      73                   9                    0
# piquet                     44                   1                    9
# berger                     43                   4                    0
# mansell                    37                   6                    0
# boutsen                    34                   2                    2
# patrese                    23                   0                    3
# nannini                    21                   3                    1
# alesi                      13                   0                    0
# capelli                     6                   0                    0
# suzuki                      6                   0                    4
# moreno                      6                   0                    6
# bernard                     5                   0                    0
# warwick                     3                   0                    0
# satoru_nakajima             3                   0                    1
# modena                      2                   0                    0
# caffi                       2                   0                    0
# gugelmin                    1                   0                    0
# larini                      0                   0                    0
# brabham                     0                   0                    0
# gary_brabham                0                   0                    0
# johansson                   0                   0                    0
# morbidelli                  0                   0                    0
# herbert                     0                   0                    0
# langes                      0                   0                    0
# tarquini                    0                   0                    0
# donnelly                    0                   0                    0
# pirro                       0                   0                    0
# barilla                     0                   0                    0
# lehto                       0                   0                    0
# martini                     0                   0                    0
# cesaris                     0                   0                    0
# giacomelli                  0                   0                    0
# grouillard                  0                   0                    0
# dalmas                      0                   0                    0
# foitek                      0                   0                    0
# alboreto                    0                   0                    0
# alliot                      0                   0                    0
# gachot                      0                   0                    0
# schneider                   0                   0                    0
#
#                  Portuguese Grand Prix  Hungarian Grand Prix  \
# senna                              6.0                   6.0
# prost                              4.0                   0.0
# piquet                             2.0                   4.0
# berger                             3.0                   0.0
# mansell                            9.0                   0.0
# boutsen                            0.0                   9.0
# patrese                            0.0                   3.0
# nannini                            0.0                   0.0
# alesi                              0.0                   0.0
# capelli                            0.0                   0.0
# suzuki                             0.0                   0.0
# moreno                             0.0                   0.0
# bernard                            0.0                   1.0
# warwick                            0.0                   2.0
# satoru_nakajima                    0.0                   0.0
# modena                             0.0                   0.0
# caffi                              0.0                   0.0
# gugelmin                           0.0                   0.0
# larini                             0.0                   0.0
# brabham                            0.0                   0.0
# gary_brabham                       NaN                   NaN
# johansson                          NaN                   NaN
# morbidelli                         0.0                   0.0
# herbert                            NaN                   NaN
# langes                             0.0                   0.0
# tarquini                           0.0                   0.0
# donnelly                           0.0                   0.0
# pirro                              0.0                   0.0
# barilla                            0.0                   0.0
# lehto                              0.0                   0.0
# martini                            0.0                   0.0
# cesaris                            0.0                   0.0
# giacomelli                         0.0                   0.0
# grouillard                         0.0                   0.0
# dalmas                             0.0                   0.0
# foitek                             0.0                   0.0
# alboreto                           0.0                   0.0
# alliot                             0.0                   0.0
# gachot                             0.0                   0.0
# schneider                          NaN                   NaN
#
#                  Brazilian Grand Prix  German Grand Prix  Italian Grand Prix  \
# senna                             4.0                9.0                 9.0
# prost                             9.0                3.0                 6.0
# piquet                            1.0                0.0                 0.0
# berger                            6.0                4.0                 4.0
# mansell                           3.0                0.0                 3.0
# boutsen                           2.0                1.0                 0.0
# patrese                           0.0                2.0                 2.0
# nannini                           6.0                0.0                 0.0
# alesi                             0.0                0.0                 0.0
# capelli                           0.0                0.0                 0.0
# suzuki                            0.0                0.0                 0.0
# moreno                            0.0                0.0                 0.0
# bernard                           0.0                0.0                 0.0
# warwick                           0.0                0.0                 0.0
# satoru_nakajima                   0.0                0.0                 1.0
# modena                            0.0                0.0                 0.0
# caffi                             0.0                0.0                 0.0
# gugelmin                          0.0                0.0                 0.0
# larini                            0.0                0.0                 0.0
# brabham                           0.0                0.0                 0.0
# gary_brabham                      NaN                NaN                 NaN
# johansson                         NaN                NaN                 NaN
# morbidelli                        NaN                NaN                 NaN
# herbert                           NaN                NaN                 NaN
# langes                            0.0                0.0                 0.0
# tarquini                          0.0                0.0                 0.0
# donnelly                          0.0                0.0                 0.0
# pirro                             0.0                0.0                 0.0
# barilla                           0.0                0.0                 0.0
# lehto                             0.0                0.0                 0.0
# martini                           0.0                0.0                 0.0
# cesaris                           0.0                0.0                 0.0
# giacomelli                        0.0                0.0                 0.0
# grouillard                        0.0                0.0                 0.0
# dalmas                            0.0                0.0                 0.0
# foitek                            0.0                0.0                 0.0
# alboreto                          0.0                0.0                 0.0
# alliot                            0.0                0.0                 0.0
# gachot                            0.0                0.0                 0.0
# schneider                         NaN                NaN                 NaN
#
#                  United States Grand Prix  French Grand Prix  \
# senna                                 9.0                4.0
# prost                                 0.0                9.0
# piquet                                3.0                3.0
# berger                                0.0                2.0
# mansell                               0.0                0.0
# boutsen                               4.0                0.0
# patrese                               0.0                1.0
# nannini                               0.0                4.0
# alesi                                 6.0                0.0
# capelli                               0.0                6.0
# suzuki                                0.0                0.0
# moreno                                0.0                0.0
# bernard                               0.0                0.0
# warwick                               0.0                0.0
# satoru_nakajima                       1.0                0.0
# modena                                2.0                0.0
# caffi                                 0.0                0.0
# gugelmin                              0.0                0.0
# larini                                0.0                0.0
# brabham                               0.0                0.0
# gary_brabham                          NaN                NaN
# johansson                             NaN                NaN
# morbidelli                            NaN                NaN
# herbert                               NaN                NaN
# langes                                0.0                0.0
# tarquini                              0.0                0.0
# donnelly                              0.0                0.0
# pirro                                 0.0                0.0
# barilla                               0.0                0.0
# lehto                                 0.0                0.0
# martini                               0.0                0.0
# cesaris                               0.0                0.0
# giacomelli                            0.0                0.0
# grouillard                            0.0                0.0
# dalmas                                0.0                0.0
# foitek                                0.0                0.0
# alboreto                              0.0                0.0
# alliot                                0.0                0.0
# gachot                                0.0                0.0
# schneider                             NaN                NaN
#
#                  San Marino Grand Prix  Australian Grand Prix  \
# senna                              0.0                    0.0
# prost                              3.0                    4.0
# piquet                             2.0                    9.0
# berger                             6.0                    3.0
# mansell                            0.0                    6.0
# boutsen                            0.0                    2.0
# patrese                            9.0                    1.0
# nannini                            4.0                    0.0
# alesi                              1.0                    0.0
# capelli                            0.0                    0.0
# suzuki                             0.0                    0.0
# moreno                             0.0                    0.0
# bernard                            0.0                    0.0
# warwick                            0.0                    0.0
# satoru_nakajima                    0.0                    0.0
# modena                             0.0                    0.0
# caffi                              0.0                    2.0
# gugelmin                           0.0                    0.0
# larini                             0.0                    0.0
# brabham                            0.0                    0.0
# gary_brabham                       NaN                    NaN
# johansson                          NaN                    NaN
# morbidelli                         NaN                    NaN
# herbert                            NaN                    NaN
# langes                             0.0                    0.0
# tarquini                           0.0                    0.0
# donnelly                           0.0                    0.0
# pirro                              0.0                    0.0
# barilla                            0.0                    0.0
# lehto                              0.0                    NaN
# martini                            0.0                    0.0
# cesaris                            0.0                    0.0
# giacomelli                         0.0                    0.0
# grouillard                         0.0                    0.0
# dalmas                             0.0                    0.0
# foitek                             0.0                    NaN
# alboreto                           0.0                    0.0
# alliot                             0.0                    0.0
# gachot                             0.0                    0.0
# schneider                          NaN                    NaN
#
#                  Spanish Grand Prix  Monaco Grand Prix  British Grand Prix  \
# senna                           0.0                9.0                 4.0
# prost                           9.0                0.0                 9.0
# piquet                          0.0                0.0                 2.0
# berger                          0.0                4.0                 0.0
# mansell                         6.0                0.0                 0.0
# boutsen                         3.0                3.0                 6.0
# patrese                         2.0                0.0                 0.0
# nannini                         0.0                3.0                 0.0
# alesi                           0.0                6.0                 0.0
# capelli                         0.0                0.0                 0.0
# suzuki                          1.0                0.0                 1.0
# moreno                          0.0                0.0                 0.0
# bernard                         0.0                1.0                 3.0
# warwick                         0.0                0.0                 0.0
# satoru_nakajima                 0.0                0.0                 0.0
# modena                          0.0                0.0                 0.0
# caffi                           0.0                0.0                 0.0
# gugelmin                        0.0                0.0                 0.0
# larini                          0.0                0.0                 0.0
# brabham                         0.0                0.0                 0.0
# gary_brabham                    NaN                NaN                 NaN
# johansson                       NaN                NaN                 NaN
# morbidelli                      NaN                NaN                 NaN
# herbert                         NaN                NaN                 NaN
# langes                          0.0                0.0                 0.0
# tarquini                        0.0                0.0                 0.0
# donnelly                        0.0                0.0                 0.0
# pirro                           0.0                0.0                 0.0
# barilla                         0.0                0.0                 0.0
# lehto                           NaN                NaN                 NaN
# martini                         0.0                0.0                 0.0
# cesaris                         0.0                0.0                 0.0
# giacomelli                      0.0                NaN                 NaN
# grouillard                      0.0                0.0                 0.0
# dalmas                          0.0                0.0                 0.0
# foitek                          NaN                NaN                 NaN
# alboreto                        0.0                0.0                 0.0
# alliot                          0.0                0.0                 0.0
# gachot                          0.0                0.0                 0.0
# schneider                       NaN                NaN                 NaN
#
#                  Belgian Grand Prix  Canadian Grand Prix
# senna                           9.0                  9.0
# prost                           6.0                  2.0
# piquet                          2.0                  6.0
# berger                          4.0                  3.0
# mansell                         0.0                  4.0
# boutsen                         0.0                  0.0
# patrese                         0.0                  0.0
# nannini                         NaN                  NaN
# alesi                           0.0                  0.0
# capelli                         0.0                  0.0
# suzuki                          0.0                  0.0
# moreno                          0.0                  0.0
# bernard                         0.0                  0.0
# warwick                         0.0                  1.0
# satoru_nakajima                 0.0                  0.0
# modena                          0.0                  0.0
# caffi                           NaN                  NaN
# gugelmin                        1.0                  0.0
# larini                          0.0                  0.0
# brabham                         NaN                  NaN
# gary_brabham                    NaN                  NaN
# johansson                       NaN                  NaN
# morbidelli                      NaN                  NaN
# herbert                         NaN                  NaN
# langes                          NaN                  NaN
# tarquini                        0.0                  0.0
# donnelly                        NaN                  NaN
# pirro                           NaN                  NaN
# barilla                         NaN                  NaN
# lehto                           NaN                  NaN
# martini                         0.0                  0.0
# cesaris                         0.0                  0.0
# giacomelli                      NaN                  NaN
# grouillard                      0.0                  0.0
# dalmas                          0.0                  0.0
# foitek                          NaN                  NaN
# alboreto                        0.0                  0.0
# alliot                          0.0                  0.0
# gachot                          0.0                  0.0
# schneider                       NaN                  NaN
